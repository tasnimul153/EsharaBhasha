# %% [markdown]
# ### Install dependencies

# %%
# !pip install tensorflow tensorflow-gpu opencv-python mediapipe sklearn matplotlib
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.9.1-cp310-cp310-win_amd64.whl (444.1 MB)
#      -------------------------------------- 444.1/444.1 MB 1.5 MB/s eta 0:00:00
# Collecting tensorflow-gpu
#   Downloading tensorflow_gpu-2.9.1-cp310-cp310-win_amd64.whl (444.1 MB)
#      -------------------------------------- 444.1/444.1 MB 1.3 MB/s eta 0:00:00
# Collecting opencv-python
#   Downloading opencv_python-4.6.0.66-cp36-abi3-win_amd64.whl (35.6 MB)
#      ---------------------------------------- 35.6/35.6 MB 1.7 MB/s eta 0:00:00
# Collecting mediapipe
#   Downloading mediapipe-0.8.10-cp310-cp310-win_amd64.whl (48.6 MB)
#      ---------------------------------------- 48.6/48.6 MB 1.7 MB/s eta 0:00:00
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting matplotlib
#   Downloading matplotlib-3.5.2-cp310-cp310-win_amd64.whl (7.2 MB)
#      ---------------------------------------- 7.2/7.2 MB 1.9 MB/s eta 0:00:00
# Collecting tensorboard<2.10,>=2.9
#   Downloading tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
#      ---------------------------------------- 5.8/5.8 MB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.12.0 in c:\users\tohir\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.16.0)
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ---------------------------------------- 65.5/65.5 kB 1.8 MB/s eta 0:00:00
# Collecting termcolor>=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting libclang>=13.0.0
#   Downloading libclang-14.0.1-py2.py3-none-win_amd64.whl (14.2 MB)
#      ---------------------------------------- 14.2/14.2 MB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\tohir\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (21.3)
# Collecting tensorflow-estimator<2.10.0,>=2.9.0rc0
#   Downloading tensorflow_estimator-2.9.0-py2.py3-none-any.whl (438 kB)
#      -------------------------------------- 438.7/438.7 kB 2.3 MB/s eta 0:00:00
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting typing-extensions>=3.6.6
#   Downloading typing_extensions-4.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: setuptools in c:\users\tohir\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (58.1.0)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.26.0-cp310-cp310-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 2.4 MB/s eta 0:00:00
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.4-cp310-cp310-win_amd64.whl (895 kB)
#      -------------------------------------- 895.5/895.5 kB 2.5 MB/s eta 0:00:00
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.46.3-cp310-cp310-win_amd64.whl (3.5 MB)
#      ---------------------------------------- 3.5/3.5 MB 2.1 MB/s eta 0:00:00
# Collecting keras-preprocessing>=1.1.1
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ---------------------------------------- 42.6/42.6 kB 2.0 MB/s eta 0:00:00
# Collecting h5py>=2.9.0
#   Downloading h5py-3.7.0-cp310-cp310-win_amd64.whl (2.6 MB)
#      ---------------------------------------- 2.6/2.6 MB 2.2 MB/s eta 0:00:00
# Collecting flatbuffers<2,>=1.12
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ---------------------------------------- 57.5/57.5 kB 1.5 MB/s eta 0:00:00
# Collecting absl-py>=1.0.0
#   Downloading absl_py-1.1.0-py3-none-any.whl (123 kB)
#      -------------------------------------- 123.7/123.7 kB 2.4 MB/s eta 0:00:00
# Collecting keras<2.10.0,>=2.9.0rc0
#   Downloading keras-2.9.0-py2.py3-none-any.whl (1.6 MB)
#      ---------------------------------------- 1.6/1.6 MB 2.5 MB/s eta 0:00:00
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting numpy>=1.20
#   Downloading numpy-1.22.4-cp310-cp310-win_amd64.whl (14.7 MB)
#      ---------------------------------------- 14.7/14.7 MB 1.8 MB/s eta 0:00:00
# Collecting wrapt>=1.11.0
#   Downloading wrapt-1.14.1-cp310-cp310-win_amd64.whl (35 kB)
# Collecting opencv-contrib-python
#   Downloading opencv_contrib_python-4.6.0.66-cp36-abi3-win_amd64.whl (42.5 MB)
#      ---------------------------------------- 42.5/42.5 MB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=19.1.0 in c:\users\tohir\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (21.4.0)
# Collecting scikit-learn
#   Downloading scikit_learn-1.1.1-cp310-cp310-win_amd64.whl (7.3 MB)
#      ---------------------------------------- 7.3/7.3 MB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\tohir\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.0.9)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.2-cp310-cp310-win_amd64.whl (55 kB)
#      ---------------------------------------- 55.3/55.3 kB 1.5 MB/s eta 0:00:00
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.33.3-py3-none-any.whl (930 kB)
#      -------------------------------------- 930.9/930.9 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tohir\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.8.2)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.1.1-cp310-cp310-win_amd64.whl (3.3 MB)
#      ---------------------------------------- 3.3/3.3 MB 2.1 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting wheel<1.0,>=0.23.0
#   Downloading wheel-0.37.1-py2.py3-none-any.whl (35 kB)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.7-py3-none-any.whl (97 kB)
#      ---------------------------------------- 97.8/97.8 kB 2.7 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      -------------------------------------- 781.3/781.3 kB 2.5 MB/s eta 0:00:00
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.7.0-py2.py3-none-any.whl (160 kB)
#      -------------------------------------- 160.7/160.7 kB 2.4 MB/s eta 0:00:00
# Collecting werkzeug>=1.0.1
#   Downloading Werkzeug-2.1.2-py3-none-any.whl (224 kB)
#      -------------------------------------- 224.9/224.9 kB 2.8 MB/s eta 0:00:00
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting requests<3,>=2.21.0
#   Downloading requests-2.28.0-py3-none-any.whl (62 kB)
#      ---------------------------------------- 62.8/62.8 kB 3.3 MB/s eta 0:00:00
# Collecting joblib>=1.0.0
#   Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
#      -------------------------------------- 307.0/307.0 kB 2.7 MB/s eta 0:00:00
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting scipy>=1.3.2
#   Downloading scipy-1.8.1-cp310-cp310-win_amd64.whl (36.9 MB)
#      ---------------------------------------- 36.9/36.9 MB 1.6 MB/s eta 0:00:00
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.8-py3-none-any.whl (39 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      -------------------------------------- 155.3/155.3 kB 1.3 MB/s eta 0:00:00
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.3-py3-none-any.whl (61 kB)
#      ---------------------------------------- 61.2/61.2 kB 1.6 MB/s eta 0:00:00
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
#      -------------------------------------- 139.0/139.0 kB 1.4 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17
#   Downloading certifi-2022.5.18.1-py3-none-any.whl (155 kB)
#      -------------------------------------- 155.2/155.2 kB 1.6 MB/s eta 0:00:00
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      ---------------------------------------- 77.1/77.1 kB 1.4 MB/s eta 0:00:00
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.0-py3-none-any.whl (151 kB)
#      -------------------------------------- 151.5/151.5 kB 1.5 MB/s eta 0:00:00
# Using legacy 'setup.py install' for sklearn, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for termcolor, since package 'wheel' is not installed.
# Installing collected packages: termcolor, tensorboard-plugin-wit, pyasn1, libclang, keras, flatbuffers, wrapt, wheel, werkzeug, urllib3, typing-extensions, threadpoolctl, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, rsa, pyasn1-modules, protobuf, pillow, oauthlib, numpy, markdown, kiwisolver, joblib, idna, grpcio, google-pasta, gast, fonttools, cycler, charset-normalizer, certifi, cachetools, absl-py, scipy, requests, opt-einsum, opencv-python, opencv-contrib-python, matplotlib, keras-preprocessing, h5py, google-auth, astunparse, scikit-learn, requests-oauthlib, mediapipe, sklearn, google-auth-oauthlib, tensorboard, tensorflow-gpu, tensorflow
#   Running setup.py install for termcolor: started
#   Running setup.py install for termcolor: finished with status 'done'
#   Running setup.py install for sklearn: started
#   Running setup.py install for sklearn: finished with status 'done'
# Successfully installed absl-py-1.1.0 astunparse-1.6.3 cachetools-5.2.0 certifi-2022.5.18.1 charset-normalizer-2.0.12 cycler-0.11.0 flatbuffers-1.12 fonttools-4.33.3 gast-0.4.0 google-auth-2.7.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.46.3 h5py-3.7.0 idna-3.3 joblib-1.1.0 keras-2.9.0 keras-preprocessing-1.1.2 kiwisolver-1.4.2 libclang-14.0.1 markdown-3.3.7 matplotlib-3.5.2 mediapipe-0.8.10 numpy-1.22.4 oauthlib-3.2.0 opencv-contrib-python-4.6.0.66 opencv-python-4.6.0.66 opt-einsum-3.3.0 pillow-9.1.1 protobuf-3.19.4 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-2.28.0 requests-oauthlib-1.3.1 rsa-4.8 scikit-learn-1.1.1 scipy-1.8.1 sklearn-0.0 tensorboard-2.9.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.9.1 tensorflow-estimator-2.9.0 tensorflow-gpu-2.9.1 tensorflow-io-gcs-filesystem-0.26.0 termcolor-1.1.0 threadpoolctl-3.1.0 typing-extensions-4.2.0 urllib3-1.26.9 werkzeug-2.1.2 wheel-0.37.1 wrapt-1.14.1

# %% [markdown]
# ### Import dependencies and function definition

# %%
import os, time, cv2 
import numpy as np 
import mediapipe as mp 
from matplotlib import pyplot as plt 
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

mp_holistic = mp.solutions.holistic 
mp_drawing = mp.solutions.drawing_utils 

def detect_features(image, model): 
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False 
    result = model.process(image)
    image.flags.writeable = True 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    return image, result

def display_landmarks(image, result): 
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(252,198,3), thickness=2, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(255,255,255), thickness=1, circle_radius=2)) 
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(252,198,3), thickness=2, circle_radius=1),  
                             mp_drawing.DrawingSpec(color=(255,255,255), thickness=1, circle_radius=2)) 
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(252,198,3), thickness=2, circle_radius=1),  
                             mp_drawing.DrawingSpec(color=(255,255,255), thickness=1, circle_radius=2))

def extract_keypoints(results): 
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, lh, rh])

def prob_viz(res, actions, input_frame):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), (255, 255, 255), -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,0), 2, cv2.LINE_AA)
    return output_frame

labels = ['1', '2', 'Amar', 'Salam', 'Nam']
actions = np.array(labels)

# %% [markdown]
# ### Demo

# %%
video = cv2.VideoCapture(1)
with mp_holistic.Holistic(
    model_complexity=1,
    min_detection_confidence=0.6,
    min_tracking_confidence=0.6
) as holistic:
    while video.isOpened(): 
        ret, frame = video.read() 
        image, results = detect_features(frame, holistic)
        display_landmarks(image, results)
        cv2.imshow("Tracking Demo", image) 
        if cv2.waitKey(10) & 0xFF == ord('q'): 
            break
    video.release() 
    cv2.destroyAllWindows()

# %% [markdown]
# ### Setup dataset folder

# %%
DATA_PATH = os.path.join('Dataset') 

number_of_videos = 30
number_of_frames = 30

inputFor = '2'
current_input = labels.index(inputFor)
directory = f'Dataset/{inputFor}'
start_folder = len(next(os.walk(directory))[1]) if os.path.exists(directory) else 0

for video_number in range(start_folder, start_folder + number_of_videos):
    os.makedirs(os.path.join(DATA_PATH, labels[current_input], str(video_number)))

# %% [markdown]
# ### Collect keypoints as features

# %%
cap = cv2.VideoCapture(1)
with mp_holistic.Holistic(
    model_complexity=1,
    min_detection_confidence=0.6,
    min_tracking_confidence=0.6
) as holistic:
    for video_number in range(start_folder, start_folder + number_of_videos):
        for frame_num in range(number_of_frames):
            ret, frame = cap.read()
            image, results = detect_features(frame, holistic)
            display_landmarks(image, results)
            if frame_num == 0: 
                cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(labels[current_input], video_number), (15,12), 
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                cv2.imshow('Collecting Features', image)
                cv2.waitKey(2000)
            else: 
                cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(labels[current_input], video_number), (15,12), 
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                cv2.imshow('Collecting Features', image)
            keypoints = extract_keypoints(results)
            npy_path = os.path.join(DATA_PATH, labels[current_input], str(video_number), str(frame_num))
            np.save(npy_path, keypoints)
            if cv2.waitKey(10) & 0xFF == ord('q'):
                break
    cap.release()
    cv2.destroyAllWindows()
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### Preprocess data

# %%
label_map = {dt:num for num, dt in enumerate(actions)}
videos, label_data = [], []
for action in actions:
    directory = f'Dataset/{action}'
    for video_number in range(len(next(os.walk(directory))[1])):
        window = []
        for frame_num in range(number_of_frames):
            res = np.load(os.path.join(DATA_PATH, action, str(video_number), "{}.npy".format(frame_num)))
            window.append(res)
        videos.append(window)
        label_data.append(label_map[action])
        
X = np.array(videos)
y = to_categorical(label_data).astype(int)
print(f"\nTotal Videos: {X.shape[0]}\nNumber of Frames(each): {X.shape[1]}\nTotal Keypoints: {X.shape[2]}")
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)
print(f"Number of trainning data: {X_train.shape[0]}\nNumber of test data: {X_test.shape[0]}")
print(np.array(videos).shape)
# Out:
# Total Videos: 800
# Number of Frames(each): 30
# Total Keypoints: 258
# Number of trainning data: 760
# Number of test data: 40
# (800, 30, 258)

# %% [markdown]
# ### Build and Train LSTM Neural Network

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(number_of_frames, X.shape[2])))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])
model.fit(X_train, y_train, epochs=100, callbacks=[tb_callback])
model.summary()

model.save('eashara.h5')
# Out:
# Epoch 1/100
# 24/24 [==============================] - 4s 88ms/step - loss: 1.4338 - categorical_accuracy: 0.4263
# Epoch 2/100
# 24/24 [==============================] - 2s 87ms/step - loss: 1.1229 - categorical_accuracy: 0.5276
# Epoch 3/100
# 24/24 [==============================] - 2s 87ms/step - loss: 0.6187 - categorical_accuracy: 0.7842
# Epoch 4/100
# 24/24 [==============================] - 2s 88ms/step - loss: 0.2969 - categorical_accuracy: 0.9066
# Epoch 5/100
# 24/24 [==============================] - 2s 87ms/step - loss: 0.1849 - categorical_accuracy: 0.9487
# Epoch 6/100
# 24/24 [==============================] - 2s 87ms/step - loss: 0.4405 - categorical_accuracy: 0.8776
# Epoch 7/100
# 24/24 [==============================] - 2s 87ms/step - loss: 0.1971 - categorical_accuracy: 0.9434
# Epoch 8/100
# 24/24 [==============================] - 2s 87ms/step - loss: 0.1760 - categorical_accuracy: 0.9474
# Epoch 9/100
# 24/24 [==============================] - 2s 87ms/step - loss: 0.1649 - categorical_accuracy: 0.9447
# Epoch 10/100
# 24/24 [==============================] - 2s 88ms/step - loss: 0.1142 - categorical_accuracy: 0.9671
# Epoch 11/100
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0887 - categorical_accuracy: 0.9724
# Epoch 12/100
# 24/24 [==============================] - 2s 99ms/step - loss: 0.0422 - categorical_accuracy: 0.9855
# Epoch 13/100
# 24/24 [==============================] - 2s 101ms/step - loss: 0.4395 - categorical_accuracy: 0.8974
# Epoch 14/100
# 24/24 [==============================] - 2s 102ms/step - loss: 1.4601 - categorical_accuracy: 0.8987
# Epoch 15/100
# 24/24 [==============================] - 2s 102ms/step - loss: 21.3443 - categorical_accuracy: 0.3066
# Epoch 16/100
# 24/24 [==============================] - 2s 101ms/step - loss: 763.2457 - categorical_accuracy: 0.2697
# Epoch 17/100
# 24/24 [==============================] - 2s 101ms/step - loss: 21.1689 - categorical_accuracy: 0.2895
# Epoch 18/100
# 24/24 [==============================] - 2s 100ms/step - loss: 1.3856 - categorical_accuracy: 0.2934
# Epoch 19/100
# 24/24 [==============================] - 2s 101ms/step - loss: 1.3851 - categorical_accuracy: 0.2724
# Epoch 20/100
# 24/24 [==============================] - 2s 101ms/step - loss: 1.3574 - categorical_accuracy: 0.3158
# Epoch 21/100
# 24/24 [==============================] - 2s 101ms/step - loss: 1.2955 - categorical_accuracy: 0.4289
# Epoch 22/100
# 24/24 [==============================] - 2s 101ms/step - loss: 1.2328 - categorical_accuracy: 0.4237
# Epoch 23/100
# 24/24 [==============================] - 2s 101ms/step - loss: 1.2099 - categorical_accuracy: 0.4605
# Epoch 24/100
# 24/24 [==============================] - 2s 102ms/step - loss: 1.1671 - categorical_accuracy: 0.4842
# Epoch 25/100
# 24/24 [==============================] - 2s 103ms/step - loss: 1.0242 - categorical_accuracy: 0.5750
# Epoch 26/100
# 24/24 [==============================] - 2s 102ms/step - loss: 1.1858 - categorical_accuracy: 0.4987
# Epoch 27/100
# 24/24 [==============================] - 2s 102ms/step - loss: 0.7800 - categorical_accuracy: 0.6882
# Epoch 28/100
# 24/24 [==============================] - 2s 102ms/step - loss: 1.1975 - categorical_accuracy: 0.5013
# Epoch 29/100
# 24/24 [==============================] - 2s 101ms/step - loss: 0.7948 - categorical_accuracy: 0.6803
# Epoch 30/100
# 24/24 [==============================] - 2s 102ms/step - loss: 0.6073 - categorical_accuracy: 0.7342
# Epoch 31/100
# 24/24 [==============================] - 2s 101ms/step - loss: 0.4893 - categorical_accuracy: 0.8079
# Epoch 32/100
# 24/24 [==============================] - 2s 101ms/step - loss: 0.3632 - categorical_accuracy: 0.8579
# Epoch 33/100
# 24/24 [==============================] - 2s 101ms/step - loss: 0.2232 - categorical_accuracy: 0.9211
# Epoch 34/100
# 24/24 [==============================] - 2s 102ms/step - loss: 0.1582 - categorical_accuracy: 0.9461
# Epoch 35/100
# 24/24 [==============================] - 2s 103ms/step - loss: 0.1798 - categorical_accuracy: 0.9395
# Epoch 36/100
# 24/24 [==============================] - 2s 104ms/step - loss: 0.1746 - categorical_accuracy: 0.9382
# Epoch 37/100
# 24/24 [==============================] - 2s 101ms/step - loss: 0.1403 - categorical_accuracy: 0.9513
# Epoch 38/100
# 24/24 [==============================] - 2s 101ms/step - loss: 0.1066 - categorical_accuracy: 0.9579
# Epoch 39/100
# 24/24 [==============================] - 2s 102ms/step - loss: 0.1366 - categorical_accuracy: 0.9526
# Epoch 40/100
# 24/24 [==============================] - 2s 99ms/step - loss: 0.1359 - categorical_accuracy: 0.9553
# Epoch 41/100
# 24/24 [==============================] - 2s 99ms/step - loss: 0.1270 - categorical_accuracy: 0.9539
# Epoch 42/100
# 24/24 [==============================] - 2s 100ms/step - loss: 0.0350 - categorical_accuracy: 0.9908
# Epoch 43/100
# 24/24 [==============================] - 2s 99ms/step - loss: 0.0362 - categorical_accuracy: 0.9895
# Epoch 44/100
# 24/24 [==============================] - 2s 97ms/step - loss: 0.0453 - categorical_accuracy: 0.9803
# Epoch 45/100
# 24/24 [==============================] - 2s 97ms/step - loss: 0.0530 - categorical_accuracy: 0.9776
# Epoch 46/100
# 24/24 [==============================] - 2s 98ms/step - loss: 0.0372 - categorical_accuracy: 0.9868
# Epoch 47/100
# 24/24 [==============================] - 2s 98ms/step - loss: 0.2480 - categorical_accuracy: 0.9289
# Epoch 48/100
# 24/24 [==============================] - 2s 98ms/step - loss: 0.0880 - categorical_accuracy: 0.9750
# Epoch 49/100
# 24/24 [==============================] - 2s 98ms/step - loss: 0.1145 - categorical_accuracy: 0.9816
# Epoch 50/100
# 24/24 [==============================] - 2s 99ms/step - loss: 0.0602 - categorical_accuracy: 0.9816
# Epoch 51/100
# 24/24 [==============================] - 2s 99ms/step - loss: 0.0495 - categorical_accuracy: 0.9882
# Epoch 52/100
# 24/24 [==============================] - 2s 100ms/step - loss: 0.0342 - categorical_accuracy: 0.9908
# Epoch 53/100
# 24/24 [==============================] - 2s 100ms/step - loss: 0.0540 - categorical_accuracy: 0.9829
# Epoch 54/100
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0966 - categorical_accuracy: 0.9697
# Epoch 55/100
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0581 - categorical_accuracy: 0.9763
# Epoch 56/100
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0430 - categorical_accuracy: 0.9855
# Epoch 57/100
# 24/24 [==============================] - 2s 102ms/step - loss: 0.0352 - categorical_accuracy: 0.9895
# Epoch 58/100
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0243 - categorical_accuracy: 0.9895
# Epoch 59/100
# 24/24 [==============================] - 2s 100ms/step - loss: 0.0743 - categorical_accuracy: 0.9816
# Epoch 60/100
# 24/24 [==============================] - 2s 101ms/step - loss: 0.3294 - categorical_accuracy: 0.8789
# Epoch 61/100
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0890 - categorical_accuracy: 0.9697
# Epoch 62/100
# 24/24 [==============================] - 2s 104ms/step - loss: 0.0496 - categorical_accuracy: 0.9855
# Epoch 63/100
# 24/24 [==============================] - 2s 101ms/step - loss: 0.1190 - categorical_accuracy: 0.9592
# Epoch 64/100
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0620 - categorical_accuracy: 0.9829
# Epoch 65/100
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0436 - categorical_accuracy: 0.9882
# Epoch 66/100
# 24/24 [==============================] - 2s 102ms/step - loss: 0.0404 - categorical_accuracy: 0.9882
# Epoch 67/100
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0397 - categorical_accuracy: 0.9855
# Epoch 68/100
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0234 - categorical_accuracy: 0.9921
# Epoch 69/100
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0248 - categorical_accuracy: 0.9908
# Epoch 70/100
# 24/24 [==============================] - 2s 102ms/step - loss: 0.0983 - categorical_accuracy: 0.9671
# Epoch 71/100
# 24/24 [==============================] - 2s 102ms/step - loss: 0.0991 - categorical_accuracy: 0.9684
# Epoch 72/100
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0253 - categorical_accuracy: 0.9908
# Epoch 73/100
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0180 - categorical_accuracy: 0.9947
# Epoch 74/100
# 24/24 [==============================] - 2s 102ms/step - loss: 0.0273 - categorical_accuracy: 0.9895
# Epoch 75/100
# 24/24 [==============================] - 2s 102ms/step - loss: 0.0229 - categorical_accuracy: 0.9934
# Epoch 76/100
# 24/24 [==============================] - 2s 100ms/step - loss: 0.0189 - categorical_accuracy: 0.9934
# Epoch 77/100
# 24/24 [==============================] - 2s 98ms/step - loss: 0.0120 - categorical_accuracy: 0.9961
# Epoch 78/100
# 24/24 [==============================] - 2s 99ms/step - loss: 0.0074 - categorical_accuracy: 0.9974
# Epoch 79/100
# 24/24 [==============================] - 2s 98ms/step - loss: 0.0048 - categorical_accuracy: 0.9987
# Epoch 80/100
# 24/24 [==============================] - 2s 100ms/step - loss: 0.0029 - categorical_accuracy: 1.0000
# Epoch 81/100
# 24/24 [==============================] - 2s 99ms/step - loss: 0.0087 - categorical_accuracy: 0.9974
# Epoch 82/100
# 24/24 [==============================] - 2s 99ms/step - loss: 0.0066 - categorical_accuracy: 0.9987
# Epoch 83/100
# 24/24 [==============================] - 2s 99ms/step - loss: 0.0438 - categorical_accuracy: 0.9816
# Epoch 84/100
# 24/24 [==============================] - 2s 100ms/step - loss: 0.0300 - categorical_accuracy: 0.9868
# Epoch 85/100
# 24/24 [==============================] - 2s 100ms/step - loss: 0.0211 - categorical_accuracy: 0.9934
# Epoch 86/100
# 24/24 [==============================] - 2s 100ms/step - loss: 0.0367 - categorical_accuracy: 0.9829
# Epoch 87/100
# 24/24 [==============================] - 2s 100ms/step - loss: 0.0245 - categorical_accuracy: 0.9934
# Epoch 88/100
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0218 - categorical_accuracy: 0.9855
# Epoch 89/100
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0327 - categorical_accuracy: 0.9908
# Epoch 90/100
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0248 - categorical_accuracy: 0.9921
# Epoch 91/100
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0599 - categorical_accuracy: 0.9855
# Epoch 92/100
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0193 - categorical_accuracy: 0.9947
# Epoch 93/100
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0088 - categorical_accuracy: 0.9961
# Epoch 94/100
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0129 - categorical_accuracy: 0.9961
# Epoch 95/100
# 24/24 [==============================] - 2s 101ms/step - loss: 0.1205 - categorical_accuracy: 0.9618
# Epoch 96/100
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0505 - categorical_accuracy: 0.9842
# Epoch 97/100
# 24/24 [==============================] - 2s 102ms/step - loss: 0.0256 - categorical_accuracy: 0.9908
# Epoch 98/100
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0073 - categorical_accuracy: 0.9974
# Epoch 99/100
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0146 - categorical_accuracy: 0.9947
# Epoch 100/100
# 24/24 [==============================] - 2s 100ms/step - loss: 0.0115 - categorical_accuracy: 0.9987
# Model: "sequential_45"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_135 (LSTM)             (None, 30, 64)            82688
#
#  lstm_136 (LSTM)             (None, 30, 128)           98816
#
#  lstm_137 (LSTM)             (None, 64)                49408
#
#  dense_135 (Dense)           (None, 64)                4160
#
#  dense_136 (Dense)           (None, 32)                2080
#
#  dense_137 (Dense)           (None, 4)                 132
#
# =================================================================
# Total params: 237,284
# Trainable params: 237,284
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Evaluation using Confusion Matrix and Accuracy

# %%
yhat = model.predict(X_test)
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 yhat = model.predict(X_test)
#       2 ytrue = np.argmax(y_test, axis=1).tolist()
#       3 yhat = np.argmax(yhat, axis=1).tolist()
#
# NameError: name 'model' is not defined

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.96875

# %% [markdown]
# ### Test in Real Time

# %%
from keras.models import load_model
model = load_model('eashara.h5')

sequence = []
sentence = []
threshold = 0.99

cap = cv2.VideoCapture(1)

with mp_holistic.Holistic(
    min_detection_confidence=0.6, 
    min_tracking_confidence=0.6
) as holistic:
    while cap.isOpened():
        ret, frame = cap.read()
        image, results = detect_features(frame, holistic)
        
        display_landmarks(image, results)
        keypoints = extract_keypoints(results)
        
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            #print(actions[np.argmax(res)])
            
            
        #. Viz logic
            if res[np.argmax(res)] >= threshold: 
                if len(sentence) > 0: 
                    if actions[np.argmax(res)] != sentence[-1]:
                        sentence.append(actions[np.argmax(res)])
                else:
                    sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30),cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        cv2.imshow('RealTime Translation', image)
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
